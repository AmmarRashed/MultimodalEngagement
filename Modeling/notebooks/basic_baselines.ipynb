# %%
import itertools

import numpy as np
import pandas as pd
from krippendorff import alpha
from sklearn.metrics import cohen_kappa_score

# %% [markdown]
# # Human Judges

# %%
engagement_cols = [
    col for col in df.columns if "session" in col and "confidence" not in col
]
confidence_cols = [col for col in df.columns if "confidence" in col]


def parse_gaming_annotations(df):
    df = (
        df.drop(["Email Address", "Timestamp"], axis=1)
        .reset_index()
        .rename(columns={"index": "annotator_id"})
    )
    # Get session IDs
    session_cols = [col.split(":")[0] for col in df.columns if ":" in col]
    session_ids = sorted(list(set(session_cols)))

    # Initialize columns for new dataframe
    result_cols = ["annotator_id", "experience", "clues"]
    for sid in session_ids:
        result_cols.extend([f"session#{sid}", f"session#{sid}_confidence"])

    # Create result rows
    result_data = []
    for _, row in df.iterrows():
        judge_row = [
            row["annotator_id"],
            row["How much gaming experience do you have personally?"],
            row[
                "What clues were you looking for to determine the player's level of engagement?"
            ],
        ]

        # Add session data
        for sid in session_ids:
            engagement = row[f"{sid}: How engaged do you think the player was?"]
            confidence = row[f"{sid}: How confident are you of that rating?"]
            judge_row.extend([engagement, confidence])

        result_data.append(judge_row)

    df = pd.DataFrame(result_data, columns=result_cols)
    df[engagement_cols + confidence_cols + ["experience"]] -= 1
    return df

# %%
df = pd.read_csv("../data/human_answers.tsv", sep="\t")
df = parse_gaming_annotations(df)
df[["annotator_id", "experience", "clues"]].to_csv("../data/Dataset/Human Panel Samples/annotators.csv", index=None)
df.head()
# Out:
#    annotator_id  experience  \
# 0             0           4
# 1             1           4
# 2             2           2
# 3             3           2
# 4             4           4
#
#                                                clues  session#201  \
# 0          Blinking, Head position, and Eye movement            2
# 1  Eye blinking Mouth movements Eye movement betw...            2
# 2  Eye movement, Facial expressions like mouth mo...            3
# 3  their eye movements, their focus on the screen...            2
# 4  Eye and head movements, blinking rate, general...            3
#
#    session#201_confidence  session#207  session#207_confidence  session#212  \
# 0                       2            2                       2            0
# 1                       3            3                       3            2
# 2                       3            3                       3            3
# 3                       3            2                       3            3
# 4                       3            4                       4            4
#
#    session#212_confidence  session#224  ...  session#869  \
# 0                       2            2  ...            2
# 1                       1            0  ...            3
# 2                       4            3  ...            2
# 3                       3            3  ...            1
# 4                       3            4  ...            4
#
#    session#869_confidence  session#870  session#870_confidence  session#872  \
# 0                       0            4                       2            0
# 1                       2            4                       3            2
# 2                       1            3                       0            4
# 3                       2            1                       3            1
# 4                       3            3                       3            2
#
#    session#872_confidence  session#880  session#880_confidence  session#885  \
# 0                       2            2                       4            4
# 1                       1            3                       2            0
# 2                       3            2                       2            2
# 3                       3            2                       3            2
# 4                       4            4                       4            4
#
#    session#885_confidence
# 0                       2
# 1                       2
# 2                       2
# 3                       3
# 4                       4
#
# [5 rows x 43 columns]

# %%
def analyze_agreement(df):
    # Extract just the engagement ratings (exclude confidence scores)
    ratings = df[engagement_cols].values

    # Krippendorff's alpha
    k_alpha = alpha(reliability_data=ratings)

    # Pairwise Cohen's Kappa
    judge_pairs = list(itertools.combinations(range(len(df)), 2))
    kappas = []
    for i, j in judge_pairs:
        kappa = cohen_kappa_score(ratings[i], ratings[j])
        kappas.append(kappa)

    avg_kappa = np.mean(kappas)

    # Raw agreement percentage
    raw_agreement = np.mean([np.mean(ratings[i] == ratings[j]) for i, j in judge_pairs])

    return {
        "krippendorff_alpha": k_alpha,
        "average_cohens_kappa": avg_kappa,
        "raw_agreement": raw_agreement,
    }

# %%
analyze_agreement(df)
# Out:
# {'krippendorff_alpha': 0.09186384578796136,
#  'average_cohens_kappa': 0.0009328166107433642,
#  'raw_agreement': 0.2258241758241758}

# %%
def analyze_agreement_with_confidence(df):
    # Get engagement and confidence columns
    ratings = df[engagement_cols].values
    confidences = df[confidence_cols].values

    # Weighted agreement based on confidence
    judge_pairs = list(itertools.combinations(range(len(df)), 2))
    weighted_agreements = []

    for i, j in judge_pairs:
        # Normalize confidence scores to 0-1
        conf_weight = (confidences[i] + confidences[j]) / (2 * confidences.max())
        agreement = ratings[i] == ratings[j]
        weighted_agreement = np.mean(agreement * conf_weight)
        weighted_agreements.append(weighted_agreement)

    return {
        "weighted_agreement": np.mean(weighted_agreements),
        "high_confidence_agreement": np.mean(
            [wa for wa, w in zip(weighted_agreements, conf_weight) if w > 0.8]
        ),
    }

# %%
analyze_agreement_with_confidence(df)
# Out:
# {'weighted_agreement': 0.15295329670329672,
#  'high_confidence_agreement': 0.09687499999999999}

# %% [markdown]
# ### Aggregating labels

# %%
agg_df = df.copy()
agg_df[engagement_cols] = agg_df[engagement_cols].replace(
    {0: 0, 1: 0, 2: 1, 3: 3, 4: 3}
)
analyze_agreement(agg_df)
# Out:
# {'krippendorff_alpha': 0.07972979758482346,
#  'average_cohens_kappa': 0.036495584029178525,
#  'raw_agreement': 0.378021978021978}

# %%
analyze_agreement_with_confidence(agg_df)
# Out:
# {'weighted_agreement': 0.26696428571428577,
#  'high_confidence_agreement': 0.23124999999999998}

# %% [markdown]
# ### Binarizing labels

# %%
bin_df = df.copy()
bin_df[engagement_cols] = bin_df[engagement_cols].replace(
    {0: 0, 1: 0, 2: 0, 3: 3, 4: 3}
)
analyze_agreement(bin_df)
# Out:
# {'krippendorff_alpha': 0.04035114738949608,
#  'average_cohens_kappa': 0.04342727663514044,
#  'raw_agreement': 0.5214285714285714}

# %%
analyze_agreement_with_confidence(bin_df)
# Out:
# {'weighted_agreement': 0.36064560439560434,
#  'high_confidence_agreement': 0.340625}

# %% [markdown]
# ### Human Performance

# %%
import numpy as np
import pandas as pd

# Reshape annotations dataframe
annotation_cols = [
    col
    for col in df.columns
    if col.startswith("session#") and not col.endswith("confidence")
]
conf_cols = [
    col
    for col in df.columns
    if col.startswith("session#") and col.endswith("confidence")
]
submissions = [int(col.split("#")[1]) for col in annotation_cols]

reshaped_df = pd.DataFrame({"submission_id": submissions})

# Add each annotator's ratings as columns
cols = []
for i in range(len(df)):
    reshaped_df[f"annotator_{i}"] = df.iloc[i][annotation_cols].astype(int).values
    reshaped_df[f"annotator_{i}_conf"] = df.iloc[i][conf_cols].astype(int).values
    
    cols.append(f"annotator_{i}")
    cols.append(f"annotator_{i}_conf")
# Merge with ground truth
merged_df = reshaped_df.merge(
    survey_stats[["participant_id", "submission_id", "engagement"]], on="submission_id"
)[["participant_id", "submission_id", "engagement"]+cols]
merged_df.head()
# Out:
#    participant_id  submission_id  engagement  annotator_0  annotator_0_conf  \
# 0             514            201           0            2                 2
# 1             514            207           4            2                 2
# 2             514            212           2            0                 2
# 3             514            224           1            2                 2
# 4             314            383           4            4                 4
#
#    annotator_1  annotator_1_conf  annotator_2  annotator_2_conf  annotator_3  \
# 0            2                 3            3                 3            2
# 1            3                 3            3                 3            2
# 2            2                 1            3                 4            3
# 3            0                 2            3                 2            3
# 4            4                 3            3                 2            3
#
#    ...  annotator_9  annotator_9_conf  annotator_10  annotator_10_conf  \
# 0  ...            2                 2             3                  3
# 1  ...            1                 3             3                  2
# 2  ...            3                 3             4                  3
# 3  ...            1                 3             3                  2
# 4  ...            2                 2             4                  3
#
#    annotator_11  annotator_11_conf  annotator_12  annotator_12_conf  \
# 0             3                  3             1                  3
# 1             3                  3             3                  3
# 2             3                  3             3                  4
# 3             3                  3             3                  3
# 4             3                  2             3                  2
#
#    annotator_13  annotator_13_conf
# 0             3                  1
# 1             2                  2
# 2             1                  3
# 3             2                  2
# 4             4                  2
#
# [5 rows x 31 columns]

# %%
merged_df.to_csv("../data/Dataset/Human Panel Samples/annotations.csv", index=None)

# %%
def aggregate_reports(reports):
    # Stack all reports
    all_reports = pd.concat(reports)

    # Group by index (metrics) and calculate mean and std
    means = all_reports.groupby(level=0).mean()
    stds = all_reports.groupby(level=0).std()

    # Combine into final format
    final_report = pd.DataFrame(
        index=means.index, columns=["precision", "recall", "f1-score", "support"]
    )

    for col in means.columns:
        final_report[col] = (
            means[col].round(2).astype(str) + " ± " + stds[col].round(2).astype(str)
        )
    return final_report.T

# %%
def evaluate_human_performance(df):
    reports = []
    annotator_columns = [ c for c in df.columns if c.startswith("annotator")]
    for annotator in annotator_columns:
        temp = df[["engagement", annotator]].dropna()
        reports.append(
            pd.DataFrame(
                classification_report(
                    temp["engagement"], temp[annotator], output_dict=True
                )
            ).T
        )
    
    return aggregate_reports(reports)

# %%
merged_df
# Out:
#     submission_id  annotator_0  annotator_1  annotator_2  annotator_3  \
# 0             201            2            2            3            2
# 1             207            2            3            3            2
# 2             212            0            2            3            3
# 3             224            2            0            3            3
# 4             383            4            4            3            3
# 5             391            4            4            2            2
# 6             404            4            0            1            1
# 7             407            2            2            3            3
# 8              50            0            1            3            2
# 9              51            1            3            0            2
# 10             52            2            4            1            3
# 11            627            0            3            3            1
# 12            639            0            1            4            1
# 13            641            0            1            3            2
# 14            642            2            0            2            4
# 15            869            2            3            2            1
# 16            870            4            4            3            1
# 17            872            0            2            4            1
# 18            880            2            3            2            2
# 19            885            4            0            2            2
#
#     annotator_4  annotator_5  annotator_6  annotator_7  annotator_8  \
# 0             3            3            4            3            4
# 1             4            2            1            1            1
# 2             4            4            4            2            4
# 3             4            3            4            2            3
# 4             2            2            1            4            4
# 5             2            3            0            3            3
# 6             4            3            2            3            4
# 7             3            2            4            3            2
# 8             1            3            1            3            0
# 9             1            1            1            2            1
# 10            3            1            3            3            2
# 11            3            1            2            3            2
# 12            2            2            1            3            2
# 13            0            2            1            4            3
# 14            1            2            2            4            3
# 15            4            1            3            4            4
# 16            3            2            2            1            3
# 17            2            2            3            2            2
# 18            4            3            3            3            4
# 19            4            2            3            1            3
#
#     annotator_9  annotator_10  annotator_11  annotator_12  annotator_13  \
# 0             2             3             3             1             3
# 1             1             3             3             3             2
# 2             3             4             3             3             1
# 3             1             3             3             3             2
# 4             2             4             3             3             4
# 5             3             4             2             3             2
# 6             2             2             2             3             3
# 7             3             4             3             1             2
# 8             1             2             3             0             0
# 9             0             1             2             1             1
# 10            2             2             4             1             0
# 11            4             2             4             1             1
# 12            1             1             4             1             3
# 13            2             3             1             1             0
# 14            3             1             1             3             0
# 15            4             2             3             0             3
# 16            1             0             3             2             2
# 17            3             1             4             1             2
# 18            1             2             3             2             2
# 19            1             3             3             3             0
#
#     engagement
# 0            0
# 1            4
# 2            2
# 3            1
# 4            4
# 5            3
# 6            2
# 7            1
# 8            3
# 9            2
# 10           4
# 11           4
# 12           2
# 13           0
# 14           1
# 15           2
# 16           3
# 17           4
# 18           1
# 19           0

# %%
agg_merged_df = merged_df.replace({0:"Low", 1:"Low", 2:"Neutral", 3:"High", 4:"High"})
bin_merged_df = merged_df.replace({0:"Low", 1:"Low", 2:"Low", 3:"High", 4:"High"})
no_neutral_merged_df = merged_df[merged_df.engagement!=2].replace({0:"Low", 1:"Low", 2:None, 3:"High", 4:"High"})
evaluate_human_performance(agg_merged_df)
# Out:
#                   High          Low      Neutral     accuracy    macro avg  \
# precision  0.38 ± 0.14  0.28 ± 0.28  0.23 ± 0.18  0.31 ± 0.13   0.3 ± 0.16
# recall     0.45 ± 0.22  0.21 ± 0.19  0.21 ± 0.12  0.31 ± 0.13  0.29 ± 0.12
# f1-score    0.4 ± 0.16  0.23 ± 0.19  0.22 ± 0.14  0.31 ± 0.13  0.28 ± 0.12
# support      8.0 ± 0.0    7.0 ± 0.0    5.0 ± 0.0  0.31 ± 0.13   20.0 ± 0.0
#
#           weighted avg
# precision  0.31 ± 0.16
# recall     0.31 ± 0.13
# f1-score   0.29 ± 0.12
# support     20.0 ± 0.0

# %%
evaluate_human_performance(bin_merged_df)
# Out:
#                   High          Low    accuracy    macro avg weighted avg
# precision  0.38 ± 0.14  0.59 ± 0.13  0.5 ± 0.12  0.49 ± 0.13  0.51 ± 0.13
# recall     0.45 ± 0.22  0.53 ± 0.18  0.5 ± 0.12  0.49 ± 0.12   0.5 ± 0.12
# f1-score    0.4 ± 0.16  0.55 ± 0.13  0.5 ± 0.12  0.47 ± 0.12  0.49 ± 0.12
# support      8.0 ± 0.0   12.0 ± 0.0  0.5 ± 0.12   20.0 ± 0.0   20.0 ± 0.0

# %%
evaluate_human_performance(no_neutral_merged_df)
# Out:
#                   High          Low     accuracy     macro avg  weighted avg
# precision  0.51 ± 0.16  0.36 ± 0.32  0.46 ± 0.17   0.43 ± 0.21   0.46 ± 0.21
# recall      0.6 ± 0.22   0.3 ± 0.28  0.46 ± 0.17   0.45 ± 0.17   0.46 ± 0.17
# f1-score   0.53 ± 0.16   0.3 ± 0.25  0.46 ± 0.17   0.42 ± 0.17   0.43 ± 0.17
# support    5.79 ± 1.12   5.0 ± 1.57  0.46 ± 0.17  10.79 ± 2.19  10.79 ± 2.19

# %% [markdown]
# ## Flow-based Model

# %%
survey_stats = pd.read_csv("../results/stats/survey.csv")
survey_stats
# Out:
#      submission_id  participant_id              game   difficulty  session_no  \
# 0               39             183            FIFA23  World Class           1
# 1               40             183            FIFA23  World Class           2
# 2               41             183            FIFA23     Semi-Pro           1
# 3               42             183            FIFA23     Semi-Pro           2
# 4               43             183            FIFA23    Legendary           1
# ..             ...             ...               ...          ...         ...
# 895            974             458  Street Fighter V          (1)           2
# 896            975             458  Street Fighter V          (1)           3
# 897            976             458  Street Fighter V          (2)           1
# 898            977             458  Street Fighter V          (2)           2
# 899            978             458  Street Fighter V          (2)           3
#
#                       start_ts                     end_ts  engagement  \
# 0    2023-10-23 11:34:04-04:00  2023-10-23 11:37:29-04:00           4
# 1    2023-10-23 11:38:12-04:00  2023-10-23 11:39:25-04:00           4
# 2    2023-10-23 11:45:34-04:00  2023-10-23 11:46:31-04:00           3
# 3    2023-10-23 11:46:55-04:00  2023-10-23 11:47:59-04:00           3
# 4    2023-10-23 11:49:29-04:00  2023-10-23 11:50:25-04:00           3
# ..                         ...                        ...         ...
# 895  2023-11-13 15:24:16-05:00  2023-11-13 15:24:59-05:00           3
# 896  2023-11-13 15:25:18-05:00  2023-11-13 15:25:47-05:00           3
# 897  2023-11-13 15:26:37-05:00  2023-11-13 15:27:19-05:00           2
# 898  2023-11-13 15:27:40-05:00  2023-11-13 15:28:20-05:00           3
# 899  2023-11-13 15:28:38-05:00  2023-11-13 15:29:14-05:00           3
#
#      interest  stress  excitement  age sex  fifa_exp  sf_exp
# 0           2       2           1   26   M         1       0
# 1           2       2           1   26   M         1       0
# 2           2       1           0   26   M         1       0
# 3           3       1           1   26   M         1       0
# 4           2       1           1   26   M         1       0
# ..        ...     ...         ...  ...  ..       ...     ...
# 895         3       0           2   26   M         1       1
# 896         2       0           2   26   M         1       1
# 897         3       1           1   26   M         1       1
# 898         3       0           1   26   M         1       1
# 899         3       1           2   26   M         1       1
#
# [900 rows x 15 columns]

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import StratifiedGroupKFold
from sklearn.preprocessing import LabelEncoder


def prepare_data(df):
    # Create experience column based on game
    df = df.assign(exp=np.where(df["game"] == "FIFA23", df["fifa_exp"], df["sf_exp"]))

    # Create difficulty encoders
    fifa_levels = [
        "Beginner",
        "Amateur",
        "Semi-Pro",
        "Professional",
        "World Class",
        "Legendary",
    ]
    sf_levels = ["(1)", "(2)", "(3)", "(4)", "(5)", "(6)", "(7)", "(8)"]

    fifa_diff_map = {level: i for i, level in enumerate(fifa_levels)}
    sf_diff_map = {level: i for i, level in enumerate(sf_levels)}

    # Encode difficulty based on game
    df["difficulty_encoded"] = df.apply(
        lambda row: (
            fifa_diff_map[row["difficulty"]]
            if row["game"] == "FIFA23"
            else sf_diff_map[row["difficulty"]]
        ),
        axis=1,
    )

    # Normalize difficulty to 0-1 range for each game
    df["difficulty_normalized"] = df.apply(
        lambda row: (
            row["difficulty_encoded"] / (len(fifa_levels) - 1)
            if row["game"] == "FIFA23"
            else row["difficulty_encoded"] / (len(sf_levels) - 1)
        ),
        axis=1,
    )

    # Prepare features and target
    X = df[["exp", "difficulty_normalized"]]
    y = df["engagement"]
    groups = df["participant_id"]

    return X, y, groups


# def create_cv_splits(X, y, groups, n_splits=5):
#     cv = StratifiedGroupKFold(n_splits=n_splits, shuffle=True, random_state=42)
#     return list(cv.split(X, y, groups))

def create_cv_splits(X, y, groups, splits_df_list):
    splits = []
    for df in splits_df_list:
        test_groups = set(df[df.Split=="test"].ParticipantId.unique())
        mask = groups.isin(test_groups)
        train_index = y[~mask].index
        test_index = y[mask].index
        splits.append((train_index, test_index))
    return splits

# Usage example:
# df = pd.read_csv('your_data.csv')
# X, y, groups = prepare_data(df)
# splits = create_cv_splits(X, y, groups)

# For each split:
# for train_idx, test_idx in splits:
#     X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
#     y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]

# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report


def train_and_evaluate(
    X,
    y,
    splits,
    model=RandomForestClassifier,
    model_kwargs={"class_weight": "balanced"},
):
    reports = []
    for train_idx, test_idx in splits:
        X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
        y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]

        clf = model(random_state=42, **model_kwargs)
        clf.fit(X_train, y_train)

        y_pred = clf.predict(X_test)
        # y_pred_proba = clf.predict_proba(X_test)

        # Get classification report as dict and convert to df
        report_dict = classification_report(y_test, y_pred, output_dict=True)
        report_df = pd.DataFrame(report_dict).transpose()

        reports.append(report_df)

    return reports


# Usage:
# reports = train_and_evaluate(X, y, splits)
# final_report = aggregate_reports(reports)

# %%
from pathlib import Path
splits_root = Path("../configs/splits/")
splits_df_list = [
    pd.read_csv(fold/"0.csv") for fold in splits_root.glob("*/")
]

# %%
# low/neutral/high
X, y, groups = prepare_data(survey_stats)
y_agg = y.map({0: "Low", 1: "Low", 2: "Neutral", 3: "High", 4: "High"})
splits = create_cv_splits(X, y_agg, groups, splits_df_list)
reports = train_and_evaluate(X, y_agg, splits)
final_report = aggregate_reports(reports)
final_report[["Low", "Neutral", "High", "accuracy", "macro avg", "weighted avg"]]
# Out:
#                     Low       Neutral           High     accuracy  \
# precision   0.27 ± 0.09    0.13 ± 0.1    0.77 ± 0.09  0.54 ± 0.08
# recall      0.57 ± 0.31   0.16 ± 0.14    0.66 ± 0.09  0.54 ± 0.08
# f1-score    0.34 ± 0.13   0.14 ± 0.12     0.7 ± 0.07  0.54 ± 0.08
# support    14.57 ± 7.52  23.29 ± 4.99  90.71 ± 18.35  0.54 ± 0.08
#
#                 macro avg    weighted avg
# precision     0.39 ± 0.06       0.6 ± 0.1
# recall        0.46 ± 0.09     0.54 ± 0.08
# f1-score       0.4 ± 0.07     0.56 ± 0.08
# support    128.57 ± 17.35  128.57 ± 17.35

# %%
# treat neutral as low
X, y, groups = prepare_data(survey_stats)
y_agg = y.map({0: "Low", 1: "Low", 2: "Low", 3: "High", 4: "High"})
splits = create_cv_splits(X, y_agg, groups, splits_df_list)
reports = train_and_evaluate(X, y_agg, splits)
final_report = aggregate_reports(reports)[["Low", "High", "accuracy", "macro avg", "weighted avg"]]
final_report
# Out:
#                     Low           High     accuracy       macro avg  \
# precision   0.43 ± 0.16    0.77 ± 0.08  0.66 ± 0.06      0.6 ± 0.08
# recall      0.45 ± 0.14    0.75 ± 0.08  0.66 ± 0.06      0.6 ± 0.07
# f1-score    0.43 ± 0.12    0.76 ± 0.05  0.66 ± 0.06     0.59 ± 0.08
# support    37.86 ± 10.9  90.71 ± 18.35  0.66 ± 0.06  128.57 ± 17.35
#
#              weighted avg
# precision     0.68 ± 0.08
# recall        0.66 ± 0.06
# f1-score      0.66 ± 0.07
# support    128.57 ± 17.35

# %%
# # exclude neutral
# X, y, groups = prepare_data(survey_stats[survey_stats.engagement != 2])
# y_agg = y.map({0: "Low", 1: "Low", 3: "High", 4: "High"})
# splits = create_cv_splits(X, y_agg, groups, splits_df_list)
# reports = train_and_evaluate(X, y_agg, splits)
# final_report = aggregate_reports(reports)
# final_report[["Low", "High", "accuracy", "macro avg", "weighted avg"]]

# %%
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, r2_score, root_mean_squared_error


def train_and_evaluate_regression(X, y, splits):
    metrics = []
    for train_idx, test_idx in splits:
        X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
        y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]

        reg = LinearRegression()
        reg.fit(X_train, y_train)

        y_pred = reg.predict(X_test)

        r2 = r2_score(y_test, y_pred)
        rmse = root_mean_squared_error(y_test, y_pred)
        mae = mean_absolute_error(y_test, y_pred)

        metrics.append({"r2": r2, "rmse": rmse, "mae": mae})

    metrics_df = pd.DataFrame(metrics)
    summary = pd.DataFrame({"mean": metrics_df.mean(), "std": metrics_df.std()})

    return summary


# Usage:
summary = train_and_evaluate_regression(X, y, splits)
summary
# Out:
#           mean       std
# r2    0.047535  0.048302
# rmse  0.970333  0.092845
# mae   0.787172  0.086716
