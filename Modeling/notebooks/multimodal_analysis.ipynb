# %%
import sys

sys.path.append("../src")

# %%
from experiments.multimodal_experiment import *
from utils import *

# %% [markdown]
# # Multimodal
# EEG + EYE + OpenFace

# %%
run_experiment(dataset_root="../../Dataset/");
# Out:
# Running Experiment on Fold 0
# Participant 407 is missing at least one modality (EYE)
# ...
#   0%|          | 0/125 [00:00<?, ?it/s]
# /home/ammar/MultimodalEngagement/notebooks/../src/models/multimodal_fusion.py:67: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   criterion = nn.BCEWithLogitsLoss(pos_weight=torch.tensor(pos_weight).to(device))
# Epochs:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 1/100:
# Train Loss: 0.3807, Train Acc: 0.4395
# Val Loss: 0.3719, Val Acc: 0.3274
# New best model saved!
# Epoch 2/100:
# Train Loss: 0.3684, Train Acc: 0.6583
# Val Loss: 0.3762, Val Acc: 0.6991
# Epoch 3/100:
# Train Loss: 0.3624, Train Acc: 0.5547
# Val Loss: 0.3796, Val Acc: 0.3540
# Epoch 4/100:
# Train Loss: 0.3364, Train Acc: 0.3935
# Val Loss: 0.3602, Val Acc: 0.4248
# New best model saved!
# Epoch 5/100:
# ...

# %%
read_reports("../results/tables/eeg_eye_openface/")
# Out:
# Accuracy: 0.6084334195261821 ± 0.09492814523402704
# ROC-AUC: 0.5182081426220945 ± 0.10994177206360137
#                      Low           High            Avg.
# Metric
# precision     0.28 ± 0.2    0.73 ± 0.08     0.51 ± 0.11
# recall       0.36 ± 0.24    0.69 ± 0.19     0.53 ± 0.09
# f1-score     0.31 ± 0.22     0.7 ± 0.11      0.51 ± 0.1
# support    36.14 ± 11.95  88.57 ± 20.45  124.71 ± 22.19

# %% [markdown]
# # Eye only

# %%
run_experiment(dataset_root="../../Dataset/", modalities=["EYE"], learning_rate=1e-5, exp_kwargs={"model_kwargs":{"dropout":0.5, "hidden_dim":64}});
# Out:
# Running Experiment on Fold 0
# Participant 407 is missing at least one modality (EYE)
# ...
#   0%|          | 0/125 [00:00<?, ?it/s]
# /home/ammar/MultimodalEngagement/Modeling/notebooks/../src/models/multimodal_fusion.py:73: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   criterion = nn.BCEWithLogitsLoss(pos_weight=torch.tensor(pos_weight).to(device))
# Epochs:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 1/100:
# Train Loss: 0.3380, Train Acc: 0.7466
# Val Loss: 0.3976, Val Acc: 0.6991
# New best model saved!
# Epoch 2/100:
# Train Loss: 0.3381, Train Acc: 0.7409
# Val Loss: 0.3956, Val Acc: 0.6991
# New best model saved!
# Epoch 3/100:
# Train Loss: 0.3346, Train Acc: 0.7370
# Val Loss: 0.3934, Val Acc: 0.6991
# New best model saved!
# Epoch 4/100:
# Train Loss: 0.3543, Train Acc: 0.7601
# Val Loss: 0.3921, Val Acc: 0.6991
# ...

# %%
read_reports("../results/tables/eye/")
# Out:
# Accuracy: 0.6413200381403196 ± 0.14714639523502543
# ROC-AUC: 0.4900358649783899 ± 0.15082562968220584
#                      Low           High            Avg.
# Metric
# precision    0.18 ± 0.19    0.63 ± 0.28      0.41 ± 0.1
# recall       0.27 ± 0.38    0.73 ± 0.38      0.5 ± 0.02
# f1-score     0.19 ± 0.25    0.67 ± 0.32     0.43 ± 0.07
# support    36.14 ± 11.95  88.71 ± 20.25  124.86 ± 22.12

# %% [markdown]
# # OpenFace Only

# %%
run_experiment(dataset_root="../../Dataset/", modalities=["OpenFace"], exp_kwargs={"model_kwargs":{"dropout":0.5, "hidden_dim":64}});
# Out:
# Running Experiment on Fold 0
# Participant 407 is missing at least one modality (OpenFace)
# ...
#   0%|          | 0/125 [00:00<?, ?it/s]
# /home/ammar/MultimodalEngagement/Modeling/notebooks/../src/models/multimodal_fusion.py:73: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   criterion = nn.BCEWithLogitsLoss(pos_weight=torch.tensor(pos_weight).to(device))
# Epochs:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 1/100:
# Train Loss: 0.4480, Train Acc: 0.4453
# Val Loss: 0.3727, Val Acc: 0.3805
# New best model saved!
# Epoch 2/100:
# Train Loss: 0.3941, Train Acc: 0.5048
# Val Loss: 0.4371, Val Acc: 0.6991
# Epoch 3/100:
# Train Loss: 0.4252, Train Acc: 0.6084
# Val Loss: 0.4477, Val Acc: 0.6991
# Epoch 4/100:
# Train Loss: 0.3792, Train Acc: 0.5374
# Val Loss: 0.3764, Val Acc: 0.6726
# Epoch 5/100:
# ...

# %%
read_reports("../results/tables/openface/")
# Out:
# Accuracy: 0.611248289946772 ± 0.15014562267302364
# ROC-AUC: 0.5064925600980739 ± 0.10154344247132223
#                      Low           High            Avg.
# Metric
# precision    0.19 ± 0.16    0.69 ± 0.11     0.44 ± 0.06
# recall        0.18 ± 0.3     0.76 ± 0.3     0.47 ± 0.04
# f1-score     0.14 ± 0.17     0.7 ± 0.21     0.42 ± 0.02
# support    36.14 ± 11.95  88.57 ± 20.45  124.71 ± 22.19

# %% [markdown]
# # EEG Only

# %%
run_experiment(dataset_root="../../Dataset/", modalities=["EEG"]);
# Out:
# Running Experiment on Fold 0
# ...
#   0%|          | 0/547 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 run_experiment(dataset_root="../../Dataset/", modalities=["EEG"]);
#
# File ~/MultimodalEngagement/Modeling/notebooks/../src/utils.py:118, in run_experiment(dataset_root, modalities, results_dir)
#     116 for i, folder in enumerate(sorted(splits_root.glob("*/"))):
#     117     print(f"Running Experiment on Fold {i}")
# --> 118     exp = MultimodalExperiment(dataset_root=dataset_root, outer_fold=folder.stem, inner_fold=0,
#     119                                modalities=modalities)
#     120     history = exp.run_training(best_model_path=f"../results/models/{exp_prefix}/{i}.pth")
#     121     pickle.dump(history, open(history_dir / f"{i}.pkl", 'wb'))
#
# ...

# %%
read_reports("../results/tables/eeg/")
